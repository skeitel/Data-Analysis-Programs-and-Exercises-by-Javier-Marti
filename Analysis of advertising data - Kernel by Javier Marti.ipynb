# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('seaborn-pastel')
# %matplotlib inline

df = pd.read_csv('Advertising.csv')
pd.set_option('display.float_format', lambda x: ('%f' % x).rstrip('.0'))
df.head()
# Out:
#    Unnamed: 0    TV  Radio  Newspaper  Sales
# 0           1 230.1   37.8       69.2   22.1
# 1           2  44.5   39.3       45.1   10.4
# 2           3  17.2   45.9       69.3    9.3
# 3           4 151.5   41.3       58.5   18.5
# 4           5 180.8   10.8       58.4   12.9

# %%
#Beginning to clean data by deleting null values
df.replace([np.inf, -np.inf], np.nan)
df.replace([np.inf, -np.inf], np.nan).dropna(subset=["TV", "Radio","Newspaper","Sales"], how="all")
# Out:
#      Unnamed: 0    TV  Radio  Newspaper  Sales
# 0             1 230.1   37.8       69.2   22.1
# 1             2  44.5   39.3       45.1   10.4
# 2             3  17.2   45.9       69.3    9.3
# 3             4 151.5   41.3       58.5   18.5
# 4             5 180.8   10.8       58.4   12.9
# 5             6   8.7   48.9         75    7.2
# 6             7  57.5   32.8       23.5   11.8
# 7             8 120.2   19.6       11.6   13.2
# 8             9   8.6    2.1          1    4.8
# 9            10 199.8    2.6       21.2   10.6
# 10           11  66.1    5.8       24.2    8.6
# 11           12 214.7     24          4   17.4
# 12           13  23.8   35.1       65.9    9.2
# 13           14  97.5    7.6        7.2    9.7
# 14           15 204.1   32.9         46     19
# 15           16 195.4   47.7       52.9   22.4
# 16           17  67.8   36.6        114   12.5
# 17           18 281.4   39.6       55.8   24.4
# 18           19  69.2   20.5       18.3   11.3
# 19           20 147.3   23.9       19.1   14.6
# 20           21 218.4   27.7       53.4     18
# 21           22 237.4    5.1       23.5   12.5
# 22           23  13.2   15.9       49.6    5.6
# 23           24 228.3   16.9       26.2   15.5
# 24           25  62.3   12.6       18.3    9.7
# 25           26 262.9    3.5       19.5     12
# 26           27 142.9   29.3       12.6     15
# 27           28 240.1   16.7       22.9   15.9
# 28           29 248.8   27.1       22.9   18.9
# 29           30  70.6     16       40.8   10.5
# ..          ...   ...    ...        ...    ...
# 170         171     5   11.6       18.4    8.4
# 171         172 164.5   20.9       47.4   14.5
# 172         173  19.6   20.1         17    7.6
# 173         174 168.4    7.1       12.8   11.7
# 174         175 222.4    3.4       13.1   11.5
# 175         176 276.9   48.9       41.8     27
# 176         177 248.4   30.2       20.3   20.2
# 177         178 170.2    7.8       35.2   11.7
# 178         179 276.7    2.3       23.7   11.8
# 179         180 165.6      1       17.6   12.6
# 180         181 156.6    2.6        8.3   10.5
# 181         182 218.5    5.4       27.4   12.2
# 182         183  56.2    5.7       29.7    8.7
# 183         184 287.6     43       71.8   26.2
# 184         185 253.8   21.3          3   17.6
# 185         186   205   45.1       19.6   22.6
# 186         187 139.5    2.1       26.6   10.3
# 187         188 191.1   28.7       18.2   17.3
# 188         189   286   13.9        3.7   15.9
# 189         190  18.7   12.1       23.4    6.7
# 190         191  39.5   41.1        5.8   10.8
# 191         192  75.5   10.8          6    9.9
# 192         193  17.2    4.1       31.6    5.9
# 193         194 166.8     42        3.6   19.6
# 194         195 149.7   35.6          6   17.3
# 195         196  38.2    3.7       13.8    7.6
# 196         197  94.2    4.9        8.1    9.7
# 197         198   177    9.3        6.4   12.8
# 198         199 283.6     42       66.2   25.5
# 199         200 232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#...and deleting unnecessary columns
del df['Unnamed: 0']

# %%
#Filling up any "0" values with NaN
df.fillna(0, inplace = True)

# %%
#Having a general glimpse at the data, we see that the value at (radio) index 127 is 0.0, so we fill it with an approx value
df.Radio[127] = 43
df.Radio[124:129]
# Out:
# 124   32.3
# 125   11.8
# 126   38.9
# 127     43
# 128     49
# Name: Radio, dtype: float64

# %%
#Plotting the graph we see that there has been high variability over time in how this company has spent its advertising budget
df[['TV','Radio','Newspaper']].plot()

# %%
#General look at the ddbb
df.describe()
# Out:
#              TV     Radio  Newspaper    Sales
# count         2         2          2        2
# mean   147.0425    23.479     30.554  14.0225
# std   85.854236 14.819546  21.778621 5.217457
# min         0.7       0.3        0.3      1.6
# 25%      74.375    10.075      12.75   10.375
# 50%      149.75     23.45      25.75     12.9
# 75%     218.825     36.65       45.1     17.4
# max       296.4      49.6        114       27

# %%
#What types of values do we have? All floats
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# Radio        200 non-null float64
# Newspaper    200 non-null float64
# Sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.3 KB

# %%
#Extra verification: how big is the database? 
df.shape
# Out:
# (200, 4)

# %%
#Now we create another column showing the combined result of the three promotional channels against sales of the product
df['TOTAL Advertising SPENT'] = df['TV'] + df['Radio'] + df['Newspaper']
df.head()
# Out:
#      TV  Radio  Newspaper  Sales  TOTAL Advertising SPENT
# 0 230.1   37.8       69.2   22.1                    337.1
# 1  44.5   39.3       45.1   10.4                    128.9
# 2  17.2   45.9       69.3    9.3                    132.4
# 3 151.5   41.3       58.5   18.5                    251.3
# 4 180.8   10.8       58.4   12.9                       25

# %%
#Now we create another column showing the combined result of the three promotional channels against sales of the product
df['TV % of Total Advertising'] = (df['TV'] *100)/df['TOTAL Advertising SPENT']
df['Radio % of Total Advertising'] = (df['Radio'] *100)/df['TOTAL Advertising SPENT']
df['Newspaper % of Total Advertising'] = (df['Newspaper'] *100)/df['TOTAL Advertising SPENT']
df.head()
# Out:
#      TV  Radio  Newspaper  Sales  TOTAL Advertising SPENT  \
# 0 230.1   37.8       69.2   22.1                    337.1
# 1  44.5   39.3       45.1   10.4                    128.9
# 2  17.2   45.9       69.3    9.3                    132.4
# 3 151.5   41.3       58.5   18.5                    251.3
# 4 180.8   10.8       58.4   12.9                       25
#
#    TV % of Total Advertising  Radio % of Total Advertising  \
# 0                  68.258677                      11.21329
# 1                  34.522886                     30.488751
# 2                  12.990937                     34.667674
# 3                   60.28651                      16.43454
# 4                      72.32                          4.32
#
#    Newspaper % of Total Advertising
# 0                         20.528033
# 1                         34.988363
# 2                          52.34139
# 3                         23.278949
# 4                             23.36

# %%
df['TV ROI in sales'] = (df['TV'] * df['TV % of Total Advertising'])/100
df['Radio ROI in sales'] = (df['Radio'] * df['Radio % of Total Advertising'])/100
df['Newspaper ROI in sales'] = (df['Newspaper'] * df['Newspaper % of Total Advertising'])/100
df.head()
# Out:
#      TV  Radio  Newspaper  Sales  TOTAL Advertising SPENT  \
# 0 230.1   37.8       69.2   22.1                    337.1
# 1  44.5   39.3       45.1   10.4                    128.9
# 2  17.2   45.9       69.3    9.3                    132.4
# 3 151.5   41.3       58.5   18.5                    251.3
# 4 180.8   10.8       58.4   12.9                       25
#
#    TV % of Total Advertising  Radio % of Total Advertising  \
# 0                  68.258677                      11.21329
# 1                  34.522886                     30.488751
# 2                  12.990937                     34.667674
# 3                   60.28651                      16.43454
# 4                      72.32                          4.32
#
#    Newspaper % of Total Advertising  TV ROI in sales  Radio ROI in sales  \
# 0                         20.528033       157.063216            4.238624
# 1                         34.988363        15.362684           11.982079
# 2                          52.34139         2.234441           15.912462
# 3                         23.278949        91.334063            6.787465
# 4                             23.36        130.75456             0.46656
#
#    Newspaper ROI in sales
# 0               14.205399
# 1               15.779752
# 2               36.272583
# 3               13.618185
# 4                13.64224

# %%
df['Total $ acquired by TV'] = (df['Sales'] * df['TV % of Total Advertising'])/100
df['Total $ acquired by Radio'] = (df['Sales'] * df['Radio % of Total Advertising'])/100
df['Total $ acquired by Newspaper'] = (df['Sales'] * df['Newspaper % of Total Advertising'])/100
df.head()
# Out:
#      TV  Radio  Newspaper  Sales  TOTAL Advertising SPENT  \
# 0 230.1   37.8       69.2   22.1                    337.1
# 1  44.5   39.3       45.1   10.4                    128.9
# 2  17.2   45.9       69.3    9.3                    132.4
# 3 151.5   41.3       58.5   18.5                    251.3
# 4 180.8   10.8       58.4   12.9                       25
#
#    TV % of Total Advertising  Radio % of Total Advertising  \
# 0                  68.258677                      11.21329
# 1                  34.522886                     30.488751
# 2                  12.990937                     34.667674
# 3                   60.28651                      16.43454
# 4                      72.32                          4.32
#
#    Newspaper % of Total Advertising  Total $ spent on TV  \
# 0                         20.528033                230.1
# 1                         34.988363                 44.5
# 2                          52.34139                 17.2
# 3                         23.278949                151.5
# 4                             23.36                180.8
#
#    Total $ acquired by TV  Total $ acquired by Radio  \
# 0               15.085168                   2.478137
# 1                 3.59038                    3.17083
# 2                1.208157                   3.224094
# 3               11.153004                    3.04039
# 4                 9.32928                    0.55728
#
#    Total $ acquired by Newspaper
# 0                       4.536695
# 1                        3.63879
# 2                       4.867749
# 3                       4.306606
# 4                        3.01344

# %%
df['TV ROI in $'] = df['Total $ acquired by TV'] - df['TV']
df['Radio ROI in $'] = df['Total $ acquired by Radio'] - df['Radio']
df['Newspaper ROI in $'] = df['Total $ acquired by Newspaper'] - df['Newspaper']
df.head()
# Out:
#      TV  Radio  Newspaper  Sales  TOTAL Advertising SPENT  \
# 0 230.1   37.8       69.2   22.1                    337.1
# 1  44.5   39.3       45.1   10.4                    128.9
# 2  17.2   45.9       69.3    9.3                    132.4
# 3 151.5   41.3       58.5   18.5                    251.3
# 4 180.8   10.8       58.4   12.9                       25
#
#    TV % of Total Advertising  Radio % of Total Advertising  \
# 0                  68.258677                      11.21329
# 1                  34.522886                     30.488751
# 2                  12.990937                     34.667674
# 3                   60.28651                      16.43454
# 4                      72.32                          4.32
#
#    Newspaper % of Total Advertising  Total $ spent on TV  \
# 0                         20.528033                230.1
# 1                         34.988363                 44.5
# 2                          52.34139                 17.2
# 3                         23.278949                151.5
# 4                             23.36                180.8
#
#    Total $ acquired by TV  Total $ acquired by Radio  \
# 0               15.085168                   2.478137
# 1                 3.59038                    3.17083
# 2                1.208157                   3.224094
# 3               11.153004                    3.04039
# 4                 9.32928                    0.55728
#
#    Total $ acquired by Newspaper  TV ROI in $  Radio ROI in $  \
# 0                       4.536695  -215.014832      -35.321863
# 1                        3.63879    -40.90962       -36.12917
# 2                       4.867749   -15.991843      -42.675906
# 3                       4.306606  -140.346996       -38.25961
# 4                        3.01344   -171.47072       -10.24272
#
#    Newspaper ROI in $
# 0          -64.663305
# 1           -41.46121
# 2          -64.432251
# 3          -54.193394
# 4           -55.38656

# %%
del df['Total $ spent on TV']

# %%
#How much variability is there on each channel? Is there one channel that is more consistent than the others?
#From this we learn that our spending on Newspaper advertising produces highly unpredictable results
print(df['TV ROI in $'].std())
print(df['Radio ROI in $'].std())
print(df['Newspaper ROI in $'].std())
# Out:
# 81.3393606249
# 13.6581127501
# 20.4789132588

# %%
#What has been the max ROI for each channel?
print(df['TV ROI in $'].max())
print(df['Radio ROI in $'].max())
print(df['Newspaper ROI in $'].max())
# Out:
# -0.677142857143
# -0.277085162423
# -0.281741867786

# %%
#In order to have a better view of the data, we transpose the columns. Now we see records more easily, from left to right
df.T
# Out:
#                                          0         1          2           3    \
# TV                                     230.1      44.5       17.2       151.5
# Radio                                   37.8      39.3       45.9        41.3
# Newspaper                               69.2      45.1       69.3        58.5
# Sales                                   22.1      10.4        9.3        18.5
# TOTAL Advertising SPENT                337.1     128.9      132.4       251.3
# TV % of Total Advertising          68.258677 34.522886  12.990937    60.28651
# Radio % of Total Advertising        11.21329 30.488751  34.667674    16.43454
# Newspaper % of Total Advertising   20.528033 34.988363   52.34139   23.278949
# Total $ acquired by TV             15.085168   3.59038   1.208157   11.153004
# Total $ acquired by Radio           2.478137   3.17083   3.224094     3.04039
# Total $ acquired by Newspaper       4.536695   3.63879   4.867749    4.306606
# TV ROI in $                      -215.014832 -40.90962 -15.991843 -140.346996
# Radio ROI in $                    -35.321863 -36.12917 -42.675906   -38.25961
# Newspaper ROI in $                -64.663305 -41.46121 -64.432251  -54.193394
#
#                                         4          5          6           7    \
# TV                                    180.8        8.7       57.5       120.2
# Radio                                  10.8       48.9       32.8        19.6
# Newspaper                              58.4         75       23.5        11.6
# Sales                                  12.9        7.2       11.8        13.2
# TOTAL Advertising SPENT                  25      132.6      113.8       151.4
# TV % of Total Advertising             72.32   6.561086  50.527241   79.392338
# Radio % of Total Advertising           4.32  36.877828  28.822496   12.945839
# Newspaper % of Total Advertising      23.36  56.561086  20.650264    7.661823
# Total $ acquired by TV              9.32928   0.472398   5.962214   10.479789
# Total $ acquired by Radio           0.55728   2.655204   3.401054    1.708851
# Total $ acquired by Newspaper       3.01344   4.072398   2.436731    1.011361
# TV ROI in $                      -171.47072  -8.227602 -51.537786 -109.720211
# Radio ROI in $                    -10.24272 -46.244796 -29.398946  -17.891149
# Newspaper ROI in $                -55.38656 -70.927602 -21.063269  -10.588639
#
#                                        8           9       ...           190  \
# TV                                     8.6       199.8     ...          39.5
# Radio                                  2.1         2.6     ...          41.1
# Newspaper                                1        21.2     ...           5.8
# Sales                                  4.8        10.6     ...          10.8
# TOTAL Advertising SPENT               11.7       223.6     ...          86.4
# TV % of Total Advertising        73.504274   89.355993     ...     45.717593
# Radio % of Total Advertising     17.948718    1.162791     ...     47.569444
# Newspaper % of Total Advertising  8.547009    9.481216     ...      6.712963
# Total $ acquired by TV            3.528205    9.471735     ...        4.9375
# Total $ acquired by Radio         0.861538    0.123256     ...        5.1375
# Total $ acquired by Newspaper     0.410256    1.005009     ...         0.725
# TV ROI in $                      -5.071795 -190.328265     ...      -34.5625
# Radio ROI in $                   -1.238462   -2.476744     ...      -35.9625
# Newspaper ROI in $               -0.589744  -20.194991     ...        -5.075
#
#                                        191        192        193         194  \
# TV                                    75.5       17.2      166.8       149.7
# Radio                                 10.8        4.1         42        35.6
# Newspaper                                6       31.6        3.6           6
# Sales                                  9.9        5.9       19.6        17.3
# TOTAL Advertising SPENT               92.3       52.9      212.4       191.3
# TV % of Total Advertising        81.798483  32.514178  78.531073   78.254051
# Radio % of Total Advertising     11.700975   7.750473  19.774011   18.609514
# Newspaper % of Total Advertising  6.500542   59.73535   1.694915    3.136435
# Total $ acquired by TV             8.09805   1.918336   15.39209   13.537951
# Total $ acquired by Radio         1.158397   0.457278   3.875706    3.219446
# Total $ acquired by Newspaper     0.643554   3.524386   0.332203    0.542603
# TV ROI in $                      -67.40195 -15.281664 -151.40791 -136.162049
# Radio ROI in $                   -9.641603  -3.642722 -38.124294  -32.380554
# Newspaper ROI in $               -5.356446 -28.075614  -3.267797   -5.457397
#
#                                         195        196         197  \
# TV                                     38.2       94.2         177
# Radio                                   3.7        4.9         9.3
# Newspaper                              13.8        8.1         6.4
# Sales                                   7.6        9.7        12.8
# TOTAL Advertising SPENT                55.7      107.2       192.7
# TV % of Total Advertising         68.581688  87.873134   91.852621
# Radio % of Total Advertising       6.642729   4.570896    4.826155
# Newspaper % of Total Advertising  24.775583    7.55597    3.321225
# Total $ acquired by TV             5.212208   8.523694   11.757135
# Total $ acquired by Radio          0.504847   0.443377    0.617748
# Total $ acquired by Newspaper      1.882944   0.732929    0.425117
# TV ROI in $                      -32.987792 -85.676306 -165.242865
# Radio ROI in $                    -3.195153  -4.456623   -8.682252
# Newspaper ROI in $               -11.917056  -7.367071   -5.974883
#
#                                          198         199
# TV                                     283.6       232.1
# Radio                                     42         8.6
# Newspaper                               66.2         8.7
# Sales                                   25.5        13.4
# TOTAL Advertising SPENT                391.8       249.4
# TV % of Total Advertising          72.383869   93.063352
# Radio % of Total Advertising       10.719755    3.448276
# Newspaper % of Total Advertising   16.896376    3.488372
# Total $ acquired by TV             18.457887   12.470489
# Total $ acquired by Radio           2.733538    0.462069
# Total $ acquired by Newspaper       4.308576    0.467442
# TV ROI in $                      -265.142113 -219.629511
# Radio ROI in $                    -39.266462   -8.137931
# Newspaper ROI in $                -61.891424   -8.232558
#
# [14 rows x 200 columns]

# %%
#We now plot the graph profile for ROI on each channel, noticing that each channel has peaked at different moments in time
df['TV ROI in $'].plot()

# %%
#As we can see above, TV is the least profitable channel, with radio closely following 
df['Radio ROI in $'].plot()

# %%
#Although fairly inconsistent, newspaper advertising has the potential to produce a very strong uptick in sales
df['Newspaper ROI in $'].plot()

# %%
#now colouring the cells...we see plenty of negative values...
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

colored = df.style.applymap(color_negative_red)
colored
# Out:
# <style  type="text/css" >
#     #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col3 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col4 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col5 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col6 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col7 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col8 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col9 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col10 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col11 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col12 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow0_col13 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col3 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col4 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col5 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col6 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col7 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col8 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col9 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col10 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col11 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col12 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow1_col13 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col3 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col4 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col5 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col6 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col7 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col8 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col9 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col10 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col11 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col12 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow2_col13 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col3 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col4 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col5 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col6 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col7 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col8 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col9 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col10 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col11 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col12 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow3_col13 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col3 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col4 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col5 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col6 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col7 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col8 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col9 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col10 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col11 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col12 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow4_col13 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col3 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col4 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col5 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col6 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col7 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col8 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col9 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col10 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col11 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col12 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow5_col13 {
#             color:  red;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow6_col0 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow6_col1 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow6_col2 {
#             color:  black;
#         }    #T_8a21ee61_8d02_11e7_983e_5800e36aafdcrow6_col3 {
#             co

# %%
#By plotting the three graphs overlapping each other, below, we notice that none of the channels have been profitable
df[['Newspaper ROI in $','TV ROI in $','Radio ROI in $']].plot()

# %%
#What channel has achieved the highest number of positive ROI values over time? Newspaper: 4 times
df['Newspaper ROI in $'].max()
# Out:
# -0.28174186778593913

# %%
#Evaluating ROI we see that Newspaper ROI has been way higher than TV ROI, over time (pending investigation of inf value)
print(df['TV ROI in $'].max())
print(df['Radio ROI in $'].max())
print(df['Newspaper ROI in $'].max())
# Out:
# -0.677142857143
# -0.277085162423
# -0.281741867786

# %%
#Now we investigage whether there is any correlation between $ spent on each channel and sales
#Correlations are not particularly high between sales and ROI on each channel
cor_radio = df[['Radio','Radio ROI in $']].corr('pearson')
cor_tv = df[['TV','TV ROI in $']].corr('pearson')
cor_newspaper = df[['Newspaper','Newspaper ROI in $']].corr('pearson')
print(cor_radio)
print(cor_tv)
print(cor_newspaper)
# Out:
#                    Radio  Radio ROI in $
# Radio                  1       -0.999305
# Radio ROI in $ -0.999305               1
#                    TV  TV ROI in $
# TV                  1    -0.999689
# TV ROI in $ -0.999689            1
#                     Newspaper  Newspaper ROI in $
# Newspaper                   1            -0.99967
# Newspaper ROI in $   -0.99967                   1

# %%
#For further verification, next we have a clearer view of the correlations, using "describe". 
#As we see in the "mean" column, correlations are not particularly high between sales and SPENDING on each channel
df[['TV','Radio','Newspaper','Sales']].corr('pearson').describe()
# Out:
#             TV    Radio  Newspaper    Sales
# count        4        4          4        4
# mean  0.470607 0.486676   0.406351 0.643303
# std   0.493658 0.402911   0.412616 0.329271
# min   0.043558 0.043558   0.056648 0.228299
# 25%   0.053375 0.266233   0.185386 0.479091
# 50%   0.419436 0.451573   0.284379 0.672456
# 75%   0.836668 0.672016   0.505344 0.836668
# max          1        1          1        1

# %%
#Finally we see what we have in the end
df.describe(include = 'all')
# Out:
#              TV     Radio  Newspaper    Sales  TOTAL Advertising SPENT  \
# count         2         2          2        2                        2
# mean   147.0425    23.479     30.554  14.0225                 201.0755
# std   85.854236 14.819546  21.778621 5.217457                92.775643
# min         0.7       0.3        0.3      1.6                     11.7
# 25%      74.375    10.075      12.75   10.375                  124.875
# 50%      149.75     23.45      25.75     12.9                   207.35
# 75%     218.825     36.65       45.1     17.4                  281.125
# max       296.4      49.6        114       27                    433.6
#
#        TV % of Total Advertising  Radio % of Total Advertising  \
# count                          2                             2
# mean                   67.663794                     14.477246
# std                    21.728212                     13.241199
# min                     1.428571                      0.263389
# 25%                    58.579719                      6.175876
# 50%                    72.956859                      10.75962
# 75%                    84.121115                     18.138617
# max                    95.845697                     80.816327
#
#        Newspaper % of Total Advertising  Total $ acquired by TV  \
# count                                 2                       2
# mean                          17.858959               10.001324
# std                           14.109358                4.973371
# min                            0.104932                0.022857
# 25%                            7.284206                 6.47975
# 50%                           14.493599               10.444951
# 75%                           23.443188               13.585006
# max                           65.473146               21.473741
#
#        Total $ acquired by Radio  Total $ acquired by Newspaper  TV ROI in $  \
# count                          2                              2            2
# mean                    1.838053                       2.183123  -137.041176
# std                      1.27684                       1.408263    81.339361
# min                     0.022915                       0.018258  -280.130812
# 25%                     0.714693                       0.989454  -205.280824
# 50%                     1.711504                       2.047267  -138.254522
# 75%                     2.782832                        3.25618   -66.965209
# max                     5.252408                       6.524725    -0.677143
#
#        Radio ROI in $  Newspaper ROI in $
# count               2                   2
# mean       -21.640947          -28.370877
# std         13.658113           20.478913
# min        -46.244796         -107.475275
# 25%        -33.996914          -41.516483
# 50%        -21.345746           -23.90637
# 75%         -9.552284          -11.567659
# max         -0.277085           -0.281742

# %%
#Let's now create a column to evaluate our sales against our advertising expenditure
df['Total Advertising ROI'] = df['Sales'] - df['TOTAL Advertising SPENT']
df.head()
# Out:
#      TV  Radio  Newspaper  Sales  TOTAL Advertising SPENT  \
# 0 230.1   37.8       69.2   22.1                    337.1
# 1  44.5   39.3       45.1   10.4                    128.9
# 2  17.2   45.9       69.3    9.3                    132.4
# 3 151.5   41.3       58.5   18.5                    251.3
# 4 180.8   10.8       58.4   12.9                       25
#
#    TV % of Total Advertising  Radio % of Total Advertising  \
# 0                  68.258677                      11.21329
# 1                  34.522886                     30.488751
# 2                  12.990937                     34.667674
# 3                   60.28651                      16.43454
# 4                      72.32                          4.32
#
#    Newspaper % of Total Advertising  Total $ acquired by TV  \
# 0                         20.528033               15.085168
# 1                         34.988363                 3.59038
# 2                          52.34139                1.208157
# 3                         23.278949               11.153004
# 4                             23.36                 9.32928
#
#    Total $ acquired by Radio  Total $ acquired by Newspaper  TV ROI in $  \
# 0                   2.478137                       4.536695  -215.014832
# 1                    3.17083                        3.63879    -40.90962
# 2                   3.224094                       4.867749   -15.991843
# 3                    3.04039                       4.306606  -140.346996
# 4                    0.55728                        3.01344   -171.47072
#
#    Radio ROI in $  Newspaper ROI in $  Total Advertising ROI
# 0      -35.321863          -64.663305                   -315
# 1       -36.12917           -41.46121                 -118.5
# 2      -42.675906          -64.432251                 -123.1
# 3       -38.25961          -54.193394                 -232.8
# 4       -10.24272           -55.38656                 -237.1

# %%
#As we can see in the graph below, the advertising efforts of this company have never been profitable
df['Total Advertising ROI'].plot()

# %%
#Total losses for the marketing campaign analyzed in this exercise: $37.410,59
df['Total Advertising ROI'].sum()
# Out:
# -37410.599999999984
