# %%
#OUR MISSION IS TO PERFORM THE FOLLOWING ACTIONS:

#1. Load the data, examine it and check for missing values etc

#2. Filter for the team ‘Arsenal’

#3. Plot Arsenal’s goals per game over time

#4. Plot Arsenal’s total goals per calendar month

#5. Calculate Arsenal’s average goals, when they play at home and when they play away from home

#6.  Examine the correlation of the home team corners and the away team corners

#7. Suggest a statistical model for the number of corners per game

# %%
#1. Load the data, examine it and check for missing values etc

#We import necessary packages to explore and work with data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#We open the file and first cursory look at the football data in file E0

df = pd.read_csv('D:\Downloads\DATASETS\general\E0.csv')
df.head()
# Out:
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A     0     0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D     1     0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H     1     0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H     1     0   H
#
#    ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  \
# 0  ...     1.61    32  -0.25     2.13     2.06     1.86     1.81  2.79  3.16
# 1  ...     1.52    33  -0.50     2.07     2.00     1.90     1.85  2.25  3.15
# 2  ...     1.77    32   0.25     1.91     1.85     2.09     2.00  3.64  3.54
# 3  ...     1.67    31   0.25     2.35     2.26     2.03     1.67  4.68  3.50
# 4  ...     2.48    34  -1.50     1.81     1.73     2.20     2.14  1.25  6.50
#
#     PSCA
# 0   2.89
# 1   3.86
# 2   2.16
# 3   1.92
# 4  14.50
#
# [5 rows x 65 columns]

# %%
#There are some of the things I usually do to verify and clean the data
# df.info #general info
# df.dtypes #Types of data present
# df.isna() #Checking for NA values present
# pd.set_option('display.max_columns', 200) #Cursory look at the data, I want to see all columns, not just a few
# df.describe() #checking unusual deviations particularly or NA values
# df.(outlier cols of any kind).plot(kind = 'bar', figsize = (15,5))

# %%
#CLEAN THE DATA
#Null values?
#df.isna().sum()
#Outliers?

# %%
'''
Legend:
FTHG and HG = Full Time Home Team Goals
FTAG and AG = Full Time Away Team Goals
HTHG = Half Time Home Team Goals
HTAG = Half Time Away Team Goals
'''

#For the sake of clarity...
#We create a  dataframe that only contains columns associated to the data we need to explore: goals and corners
#We name this new dataframe Only Goals And Corners (ogac)

ogac = df[['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HTHG', 'HTAG', 'HC','AC']]
ogac.head()
# Out:
#        Date        HomeTeam    AwayTeam  FTHG  FTAG  HTHG  HTAG  HC  AC
# 0  13/08/16         Burnley     Swansea     0     1     0     0   7   4
# 1  13/08/16  Crystal Palace   West Brom     0     1     0     0   3   6
# 2  13/08/16         Everton   Tottenham     1     1     1     0   5   6
# 3  13/08/16            Hull   Leicester     2     1     1     0   5   3
# 4  13/08/16        Man City  Sunderland     2     1     1     0   9   6

# %%
#2. Filter for the team ‘Arsenal’
#We create a new dataframe with 'Arsenal' either playing home OR away:

only_arsenal = ogac[(ogac.HomeTeam == 'Arsenal')|(ogac.AwayTeam == 'Arsenal')]
only_arsenal.head()
# Out:
#         Date   HomeTeam     AwayTeam  FTHG  FTAG  HTHG  HTAG  HC  AC
# 7   14/08/16    Arsenal    Liverpool     3     4     1     1   5   4
# 12  20/08/16  Leicester      Arsenal     0     0     0     0   2   7
# 27  27/08/16    Watford      Arsenal     1     3     0     3   3   2
# 30  10/09/16    Arsenal  Southampton     2     1     1     1   6   1
# 42  17/09/16       Hull      Arsenal     1     4     0     1   2   4

# %%
#How many matches has Arsenal played in total? Response: 38
only_arsenal.count()
# Out:
# Date        38
# HomeTeam    38
# AwayTeam    38
# FTHG        38
# FTAG        38
# HTHG        38
# HTAG        38
# HC          38
# AC          38
# dtype: int64

# %%
#Create column with home goals
only_arsenal['goals_at_home'] = only_arsenal.loc[only_arsenal['HomeTeam'] == 'Arsenal', 'FTHG']
# Out:
# D:\Program files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Create column with away goals
only_arsenal['goals_away'] = only_arsenal.loc[only_arsenal['AwayTeam'] == 'Arsenal', 'FTAG']
only_arsenal
# Out:
# D:\Program files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Date        HomeTeam        AwayTeam  FTHG  FTAG  HTHG  HTAG  HC  AC  \
# 7    14/08/16         Arsenal       Liverpool     3     4     1     1   5   4
# 12   20/08/16       Leicester         Arsenal     0     0     0     0   2   7
# 27   27/08/16         Watford         Arsenal     1     3     0     3   3   2
# 30   10/09/16         Arsenal     Southampton     2     1     1     1   6   1
# 42   17/09/16            Hull         Arsenal     1     4     0     1   2   4
# 50   24/09/16         Arsenal         Chelsea     3     0     3     0   9   1
# 66   02/10/16         Burnley         Arsenal     0     1     0     0   2   6
# 70   15/10/16         Arsenal         Swansea     3     2     2     1   5   6
# 80   22/10/16         Arsenal   Middlesbrough     0     0     0     0   8   3
# 93   29/10/16      Sunderland         Arsenal     1     4     0     1   0   8
# 105  06/11/16         Arsenal       Tottenham     1     1     1     0   7   2
# 112  19/11/16      Man United         Arsenal     1     1     0     0  10   4
# 126  27/11/16         Arsenal     Bournemouth     3     1     1     1   3  10
# 136  03/12/16        West Ham         Arsenal     1     5     0     1   3   2
# 140  10/12/16         Arsenal           Stoke     3     1     1     1   7   7
# 151  13/12/16         Everton         Arsenal     2     1     1     1   8   3
# 167  18/12/16        Man City         Arsenal     2     1     0     1   8   1
# 170  26/12/16         Arsenal       West Brom     1     0     0     0   6   5
# 188  01/01/17         Arsenal  Crystal Palace     2     0     1     0   8   4
# 196  03/01/17     Bournemouth         Arsenal     3     3     2     0   4   7
# 204  14/01/17         Swansea         Arsenal     0     4     0     1   3   2
# 217  22/01/17         Arsenal         Burnley     2     1     0     0  10   4
# 220  31/01/17         Arsenal         Watford     1     2     0     2   9   5
# 230  04/02/17         Chelsea         Arsenal     3     1     1     0  10  13
# 240  11/02/17         Arsenal            Hull     2     0     1     0   3   8
# 259  04/03/17       Liverpool         Arsenal     3     1     2     0   9   3
# 278  18/03/17       West Brom         Arsenal     3     1     1     1   4   5
# 291  02/04/17         Arsenal        Man City     2     2     1     2   3   8
# 297  05/04/17         Arsenal        West Ham     3     0     0     0   5   0
# 312  10/04/17  Crystal Palace         Arsenal     3     0     1     0   5   8
# 322  17/04/17   Middlesbrough         Arsenal     1     2     0     1   2   4
# 330  26/04/17         Arsenal       Leicester     1     0     0     0  12   1
# 342  30/04/17       Tottenham         Arsenal     2     0     0     0  14   5
# 351  07/05/17         Arsenal      Man United     2     0     0     0   5   9
# 354  10/05/17     Southampton         Arsenal     0     2     0     0   8   5
# 360  13/05/17           Stoke         Arsenal     1     4     0     1   7   6
# 366  16/05/17         Arsenal      Sunderland     2     0     0     0  17   3
# 370  21/05/17         Arsenal         Everton     3     1     2     0   4   6
#
#      goals_at_home  goals_away
# 7              3.0         NaN
# 12             NaN         0.0
# 27             NaN         3.0
# 30             2.0         NaN
# 42             NaN         4.0
# 50             3.0         NaN
# 66             NaN         1.0
# 70             3.0         NaN
# 80             0.0         NaN
# 93             NaN         4.0
# 105            1.0         NaN
# 112            NaN         1.0
# 126            3.0         NaN
# 136            NaN         5.0
# 140            3.0         NaN
# 151            NaN         1.0
# 167            NaN         1.0
# 170            1.0         NaN
# 188            2.0         NaN
# 196            NaN         3.0
# 204            NaN         4.0
# 217            2.0         NaN
# 220            1.0         NaN
# 230            NaN         1.0
# 240            2.0         NaN
# 259            NaN         1.0
# 278            NaN         1.0
# 291            2.0         NaN
# 297            3.0         NaN
# 312            NaN         0.0
# 322            NaN         2.0
# 330            1.0         NaN
# 342            NaN         0.0
# 351            2.0         NaN
# 354            NaN         2.0
# 360            NaN         4.0
# 366            2.0         NaN
# 370            3.0         NaN

# %%
only_arsenal['goals_at_home'].fillna(0, inplace = True)
only_arsenal['goals_away'].fillna(0, inplace = True)
only_arsenal.head()
# Out:
# D:\Program files\Anaconda\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#         Date   HomeTeam     AwayTeam  FTHG  FTAG  HTHG  HTAG  HC  AC  \
# 7   14/08/16    Arsenal    Liverpool     3     4     1     1   5   4
# 12  20/08/16  Leicester      Arsenal     0     0     0     0   2   7
# 27  27/08/16    Watford      Arsenal     1     3     0     3   3   2
# 30  10/09/16    Arsenal  Southampton     2     1     1     1   6   1
# 42  17/09/16       Hull      Arsenal     1     4     0     1   2   4
#
#     goals_at_home  goals_away
# 7             3.0         0.0
# 12            0.0         0.0
# 27            0.0         3.0
# 30            2.0         0.0
# 42            0.0         4.0

# %%
#Create "total_goals" column
only_arsenal['total_goals'] = only_arsenal['goals_at_home'] + only_arsenal['goals_away']
# Out:
# D:\Program files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
only_arsenal.head()
# Out:
#         Date   HomeTeam     AwayTeam  FTHG  FTAG  HTHG  HTAG  HC  AC  \
# 7   14/08/16    Arsenal    Liverpool     3     4     1     1   5   4
# 12  20/08/16  Leicester      Arsenal     0     0     0     0   2   7
# 27  27/08/16    Watford      Arsenal     1     3     0     3   3   2
# 30  10/09/16    Arsenal  Southampton     2     1     1     1   6   1
# 42  17/09/16       Hull      Arsenal     1     4     0     1   2   4
#
#     goals_at_home  goals_away  total_goals
# 7             3.0         0.0          3.0
# 12            0.0         0.0          0.0
# 27            0.0         3.0          3.0
# 30            2.0         0.0          2.0
# 42            0.0         4.0          4.0

# %%
# ALL ARSENAL GOALS OVER TIME, PLOTTED 
plot = only_arsenal.plot(x='Date', y='total_goals', kind = 'bar', figsize = (25,5))
plt.title('Total Arsenal goals')
plt.xlabel = 'Date of match'
plt.ylabel = 'Number of goals'

# for i, v in enumerate(only_arsenal.total_goals):
#     plt.text(xlocs[i] - 0.25, v + 0.01, str(v))

# plt.figure(figsize = (15,5))
# plt.scatter(x=only_arsenal['Date'], y=only_arsenal['total_goals'])
# plt.title('Total Arsenal goals')
# plt.xlabel = 'Date of match'
# plt.ylabel = 'Number of goals'

# %%
print(only_arsenal.index)
# Out:
# Int64Index([  7,  12,  27,  30,  42,  50,  66,  70,  80,  93, 105, 112, 126,
#             136, 140, 151, 167, 170, 188, 196, 204, 217, 220, 230, 240, 259,
#             278, 291, 297, 312, 322, 330, 342, 351, 354, 360, 366, 370],
#            dtype='int64')

# %%
#Converting Date col to date object
only_arsenal['Date'] = pd.to_datetime(only_arsenal['Date'])
# Out:
# D:\Program files\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
only_arsenal1 = only_arsenal
only_arsenal1.set_index('Date', inplace = True)
only_arsenal1.index
# Out:
# DatetimeIndex(['2016-08-14', '2016-08-20', '2016-08-27', '2016-10-09',
#                '2016-09-17', '2016-09-24', '2016-02-10', '2016-10-15',
#                '2016-10-22', '2016-10-29', '2016-06-11', '2016-11-19',
#                '2016-11-27', '2016-03-12', '2016-10-12', '2016-12-13',
#                '2016-12-18', '2016-12-26', '2017-01-01', '2017-03-01',
#                '2017-01-14', '2017-01-22', '2017-01-31', '2017-04-02',
#                '2017-11-02', '2017-04-03', '2017-03-18', '2017-02-04',
#                '2017-05-04', '2017-10-04', '2017-04-17', '2017-04-26',
#                '2017-04-30', '2017-07-05', '2017-10-05', '2017-05-13',
#                '2017-05-16', '2017-05-21'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
monthly = only_arsenal1.total_goals.resample('M').mean()
monthly.fillna(0, inplace = True)
monthly
# Out:
# Date
# 2016-02-29    1.00
# 2016-03-31    5.00
# 2016-04-30    0.00
# 2016-05-31    0.00
# 2016-06-30    1.00
# 2016-07-31    0.00
# 2016-08-31    2.00
# 2016-09-30    3.50
# 2016-10-31    2.40
# 2016-11-30    2.00
# 2016-12-31    1.00
# 2017-01-31    2.25
# 2017-02-28    2.00
# 2017-03-31    2.00
# 2017-04-30    1.00
# 2017-05-31    3.00
# 2017-06-30    0.00
# 2017-07-31    2.00
# 2017-08-31    0.00
# 2017-09-30    0.00
# 2017-10-31    1.00
# 2017-11-30    2.00
# Freq: M, Name: total_goals, dtype: float64

# %%
#4. Plot Arsenal’s total goals per calendar month
monthly.plot(kind = 'bar', figsize = (15,5))

# %%
#3. Plot Arsenal’s goals per game over time

#We explore the goals scored at home
Ars_home_goals = only_arsenal[only_arsenal.HomeTeam.str.contains('Arsenal')]
#Ars_home_goals.FTHG.plot(kind = 'bar')
total_home = Ars_home_goals.FTHG.sum()
print(total_home, 'goals at home')

#We explore the goals scored away from home
Ars_away_goals = only_arsenal[only_arsenal.AwayTeam.str.contains('Arsenal')] 
#Ars_away_goals.FTAG.plot(kind = 'bar')
total_away = Ars_away_goals.FTAG.sum()
print(total_away,'goals away from home')

#We have a total of goals and print it out
total_goals = Ars_home_goals.FTHG.sum() + Ars_away_goals.FTAG.sum()
print('At home and away, Arsenal has scored a total of',total_goals, 'goals, for the period measured')

#All Arsenal goals, home and away, plotted
#only_arsenal[['FTHG', 'FTAG']].plot(kind = 'bar', figsize = (10, 5))

#only_arsenal.plot(x = 'Date', y = ['FTHG', 'FTAG'], kind = 'bar', figsize = (15,5))
#only_arsenal

# def is_home1(x):
#     if x == 'Arsenal':
#         return only_arsenal['FTHG']
#     return 0

# only_arsenal['test1'] = only_arsenal.HomeTeam.apply(is_home1)
only_arsenal
# Out:
# 39 goals at home
# 38 goals away from home
# At home and away, Arsenal has scored a total of 77 goals, for the period measured
#                   HomeTeam        AwayTeam  FTHG  FTAG  HTHG  HTAG  HC  AC  \
# Date
# 2016-08-14         Arsenal       Liverpool     3     4     1     1   5   4
# 2016-08-20       Leicester         Arsenal     0     0     0     0   2   7
# 2016-08-27         Watford         Arsenal     1     3     0     3   3   2
# 2016-10-09         Arsenal     Southampton     2     1     1     1   6   1
# 2016-09-17            Hull         Arsenal     1     4     0     1   2   4
# 2016-09-24         Arsenal         Chelsea     3     0     3     0   9   1
# 2016-02-10         Burnley         Arsenal     0     1     0     0   2   6
# 2016-10-15         Arsenal         Swansea     3     2     2     1   5   6
# 2016-10-22         Arsenal   Middlesbrough     0     0     0     0   8   3
# 2016-10-29      Sunderland         Arsenal     1     4     0     1   0   8
# 2016-06-11         Arsenal       Tottenham     1     1     1     0   7   2
# 2016-11-19      Man United         Arsenal     1     1     0     0  10   4
# 2016-11-27         Arsenal     Bournemouth     3     1     1     1   3  10
# 2016-03-12        West Ham         Arsenal     1     5     0     1   3   2
# 2016-10-12         Arsenal           Stoke     3     1     1     1   7   7
# 2016-12-13         Everton         Arsenal     2     1     1     1   8   3
# 2016-12-18        Man City         Arsenal     2     1     0     1   8   1
# 2016-12-26         Arsenal       West Brom     1     0     0     0   6   5
# 2017-01-01         Arsenal  Crystal Palace     2     0     1     0   8   4
# 2017-03-01     Bournemouth         Arsenal     3     3     2     0   4   7
# 2017-01-14         Swansea         Arsenal     0     4     0     1   3   2
# 2017-01-22         Arsenal         Burnley     2     1     0     0  10   4
# 2017-01-31         Arsenal         Watford     1     2     0     2   9   5
# 2017-04-02         Chelsea         Arsenal     3     1     1     0  10  13
# 2017-11-02         Arsenal            Hull     2     0     1     0   3   8
# 2017-04-03       Liverpool         Arsenal     3     1     2     0   9   3
# 2017-03-18       West Brom         Arsenal     3     1     1     1   4   5
# 2017-02-04         Arsenal        Man City     2     2     1     2   3   8
# 2017-05-04         Arsenal        West Ham     3     0     0     0   5   0
# 2017-10-04  Crystal Palace         Arsenal     3     0     1     0   5   8
# 2017-04-17   Middlesbrough         Arsenal     1     2     0     1   2   4
# 2017-04-26         Arsenal       Leicester     1     0     0     0  12   1
# 2017-04-30       Tottenham         Arsenal     2     0     0     0  14   5
# 2017-07-05         Arsenal      Man United     2     0     0     0   5   9
# 2017-10-05     Southampton         Arsenal     0     2     0     0   8   5
# 2017-05-13           Stoke         Arsenal     1     4     0     1   7   6
# 2017-05-16         Arsenal      Sunderland     2     0     0     0  17   3
# 2017-05-21         Arsenal         Everton     3     1     2     0   4   6
#
#             goals_at_home  goals_away  total_goals
# Date
# 2016-08-14            3.0         0.0          3.0
# 2016-08-20            0.0         0.0          0.0
# 2016-08-27            0.0         3.0          3.0
# 2016-10-09            2.0         0.0          2.0
# 2016-09-17            0.0         4.0          4.0
# 2016-09-24            3.0         0.0          3.0
# 2016-02-10            0.0         1.0          1.0
# 2016-10-15            3.0         0.0          3.0
# 2016-10-22            0.0         0.0          0.0
# 2016-10-29            0.0         4.0          4.0
# 2016-06-11            1.0         0.0          1.0
# 2016-11-19            0.0         1.0          1.0
# 2016-11-27            3.0         0.0          3.0
# 2016-03-12            0.0         5.0          5.0
# 2016-10-12            3.0         0.0          3.0
# 2016-12-13            0.0         1.0          1.0
# 2016-12-18            0.0         1.0          1.0
# 2016-12-26            1.0         0.0          1.0
# 2017-01-01            2.0         0.0          2.0
# 2017-03-01            0.0         3.0          3.0
# 2017-01-14            0.0         4.0          4.0
# 2017-01-22            2.0         0.0          2.0
# 2017-01-31            1.0         0.0          1.0
# 2017-04-02            0.0         1.0          1.0
# 2017-11-02            2.0         0.0          2.0
# 2017-04-03            0.0         1.0          1.0
# 2017-03-18            0.0         1.0          1.0
# 2017-02-04            2.0         0.0          2.0
# 2017-05-04            3.0         0.0          3.0
# 2017-10-04            0.0         0.0          0.0
# 2017-04-17            0.0         2.0          2.0
# 2017-04-26            1.0         0.0          1.0
# 2017-04-30            0.0         0.0          0.0
# 2017-07-05            2.0         0.0          2.0
# 2017-10-05            0.0         2.0          2.0
# 2017-05-13            0.0         4.0          4.0
# 2017-05-16            2.0         0.0          2.0
# 2017-05-21            3.0         0.0          3.0

# %%
#5. Calculate Arsenal’s average goals, when they play at home and when they play away from home

avg_at_home =  only_arsenal.goals_at_home.mean()
avg_away =  only_arsenal.goals_away.mean()

#Plotting Arsenal's goals at HOME
Ars_home_goals.FTHG.plot(kind = 'bar')

print('The average of goals of Arsenal when playing at home is', avg_away, 'goals')
print('The average of goals of Arsenal when away from home is', avg_at_home, 'goals')
# Out:
# The average of goals of Arsenal when playing at home is 1.0 goals
# The average of goals of Arsenal when away from home is 1.0263157894736843 goals

# %%
#Arsenal goals AWAY from home
Ars_away_goals.FTAG.plot(kind = 'bar')

# %%
#6.  Examine the correlation of the home team corners and the away team corners
import seaborn as sns
corr = only_arsenal.corr()
corr = (corr)
sns.heatmap(corr,
           xticklabels = corr.HC.values,
           yticklabels = corr.AC.values)

#Based on the correlation graph...
#We could say that there appears NOT to be any significant correlation between the home and away team corners

# %%
#7. Suggest a statistical model for the number of corners per game

# %%
df['AC'].corr(df['HC'])
# Out:
# -0.29572422767592293

# %%
#7. Suggest a statistical model for the number of corners per game
f = pd.read_csv('D:\Downloads\DATASETS\general\E0.csv', comment='#')

# Corners are specified in HC and AC, depending if Arsenal is playing
# home or away.
team = 'Arsenal'
sub = df[(df.HomeTeam == team) | (df.AwayTeam == team)]
corners = pd.Series(np.where(sub.HomeTeam == team, sub.HC, sub.AC))
corners.head()
# Out:
# 0    5
# 1    7
# 2    2
# 3    6
# 4    4
# dtype: int64

# %%
# By visual inspection, the corner distributions appears to be
# following a skew-normal distribution.
import scipy
from scipy.stats import norm

x = np.linspace(0, 16)
params = skewnorm.fit(corners)
y = skewnorm.pdf(x, *params) #loc=mean, scale=sigma)
corners.hist(bins=10, normed=True, label='Observed corners')
plt.plot(x, y, label='Fit')
#plt.xlabel('# Corners / Match', size=14)
#plt.ylabel('Probability', size=14)
plt.legend()
# Out:
# D:\Program files\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = df.drop(columns=['genre'])
y = df['genre']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

model = DecisionTreeClassifier()
model.fit(X_train,y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)
score

# %%
#USING JOBLIB TO DO MODEL PERSISTENCE (RECORDING AND RETRIEVING THE MODEL)
from sklearn.tree import DecisionTreeClassifier
from sklearn.externals import joblib #library to save and load models

X = df.drop(columns=['genre'])
y = df['genre']
#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

model = DecisionTreeClassifier()
model.fit(X, y)
#predictions = model.predict(X_test)
#predictions = model.predict([[21, 1], [25,2]])

joblib.dump(model, 'music-recommender.joblib')

#WHEN WE EXECUTE THIS THE MODEL AS SEEN ON THIS CELL, IS SAVED, IN SAME DIRECTORY

# %%
#LOADING THE MODEL AND MAKING PREDICTIONS

joblib.load('music-recommender.joblib')
predictions = model.predict([[21, 1],[29,1]]) 
#what music will someone of age 21 and gender 1 like?
predictions

# %%
#VISUALIZING A TREE
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

X = df.drop(columns=['genre'])
y = df['genre']

model = DecisionTreeClassifier()
model.fit(X, y)

#Tree visualization with graphviz
tree.export_graphviz(model, out_file = 'music-recommender.dot',
                     feature_names = ['age', 'gender'],
                     class_names = sorted(y.unique()),
                     label = 'all',
                     rounded = True, 
                     filled = True)


#predictions = model.predict(X_test)
#predictions = model.predict([[21, 1], [25,2]])
